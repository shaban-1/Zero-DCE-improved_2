# %% [markdown]
# <a href="https://colab.research.google.com/github/shaban-1/Zero-DCE-improved/blob/master/%D0%9E%D0%B1%D1%83%D1%87%D0%B8%D0%BB%20%D0%BD%D0%B0%20%D0%B4%D0%B0%D1%82%D0%B0%D1%81%D0%B5%D1%82%D0%B5%20%D0%B8%D0%B7%20%D0%BA%D0%B0%D1%80%D1%82%D0%B8%D0%BD%D0%BE%D0%BA%20%D1%83%D0%B7%D0%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %rm -rf Zero-DCE-improved/
# !git clone https://github.com/shaban-1/Zero-DCE-improved.git
# Out:
# Cloning into 'Zero-DCE-improved'...
# remote: Enumerating objects: 3837, done.
# remote: Total 3837 (delta 0), reused 0 (delta 0), pack-reused 3837 (from 1)
# Receiving objects: 100% (3837/3837), 305.33 MiB | 27.62 MiB/s, done.
# Resolving deltas: 100% (149/149), done.
# Updating files: 100% (3759/3759), done.

# %%
# !python -m pip install -r Zero-DCE-improved/src/requirements.txt
# Out:
# ...
#   Using cached numpy-1.20.1.zip (7.8 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached opencv-python-4.5.4.58.tar.gz (89.8 MB)
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Installing build dependencies ... error
# error: subprocess-exited-with-error
#
# × pip subprocess to install build dependencies did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
# %cd Zero-DCE-improved/src
# Out:
# /content/Zero-DCE-improved/src

# %%
#!python lowlight_test.py
#!python lowlight_train.py
# !python lowlight_train.py \
    --lowlight_images_path "/content/Zero-DCE-improved/src/data/normal_maligant_benign_data/" \
    --num_epochs 100
# Out:
# 2025-02-20 20:11:40.458055: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1740082300.496686   25371 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1740082300.508145   25371 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-20 20:11:40.542603: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# %matplotlib inline
# !python clahe_and_zero.py
# Out:
# Результаты для 25.jpg:
#   CLAHE Metrics:
#     MSE: 0.0066, PSNR: 21.7735, SSIM: 0.5003
#   Zero-DCE Metrics:
#     MSE: 0.0059, PSNR: 22.2653, SSIM: 0.6468
# --------------------------------------------------
# Результаты для 20.jpg:
#   CLAHE Metrics:
#     MSE: 0.0090, PSNR: 20.4686, SSIM: 0.4522
#   Zero-DCE Metrics:
#     MSE: 0.0073, PSNR: 21.3432, SSIM: 0.6198
# --------------------------------------------------
# Результаты для 60.jpg:
#   CLAHE Metrics:
#     MSE: 0.0398, PSNR: 13.9993, SSIM: 0.4787
#   Zero-DCE Metrics:
#     MSE: 0.0180, PSNR: 17.4445, SSIM: 0.7947
# --------------------------------------------------
# Результаты для 14.jpg:
#   CLAHE Metrics:
#     MSE: 0.0077, PSNR: 21.1284, SSIM: 0.4568
#   Zero-DCE Metrics:
#     MSE: 0.0066, PSNR: 21.7847, SSIM: 0.7675
# --------------------------------------------------
# Результаты для 47.jpg:
#   CLAHE Metrics:
#     MSE: 0.0126, PSNR: 18.9971, SSIM: 0.7985
#   Zero-DCE Metrics:
# ...

# %%
# Добавьте в код перед созданием DataLoader:
print("Проверка доступа к файлам:")
# !ls -la "/content/Zero-DCE-improved/src/data/normal_maligant_benign_data" | head -n 5
# Out:
# Проверка доступа к файлам:
# total 264236
# drwxr-xr-x 2 root root  69632 Feb 20 19:29 .
# drwxr-xr-x 7 root root   4096 Feb 20 19:29 ..
# -rw-r--r-- 1 root root    291 Feb 20 19:29 benign (100)_mask_1.png
# -rw-r--r-- 1 root root    395 Feb 20 19:29 benign (100)_mask.png
